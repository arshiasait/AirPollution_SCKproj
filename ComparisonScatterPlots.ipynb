# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime as dt
import datetime
import csv
import math
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from coordinateSystems import GeographicSystem
from coordinateSystems import TangentPlaneCartesianSystem

# %%
# IDEA funtion that combines all data into one csv

# %%
# IDEA use ten percents and compare weather

# %%
tenCO = pd.read_csv('CO_ten_SCK1.csv')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_UP'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_UP')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_DN'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_DN')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_RH'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_RH')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_TF'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_TF')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_WD'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_TF')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['FS_WS'])
ax.set_xlabel('CO')
ax.set_ylabel('FS_TF')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_CO'])
ax.set_xlabel('CO')
ax.set_ylabel('CO')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_DB'])
ax.set_xlabel('CO')
ax.set_ylabel('DB')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_LX'])
ax.set_xlabel('CO')
ax.set_ylabel('LX')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_NO2'])
ax.set_xlabel('CO')
ax.set_ylabel('NO2')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_RH'])
ax.set_xlabel('CO')
ax.set_ylabel('RH')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['SCK1_TC'])
ax.set_xlabel('CO')
ax.set_ylabel('TC')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['V_r'])
ax.set_xlabel('CO')
ax.set_ylabel('V_r')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['bearing(deg)'])
ax.set_xlabel('CO')
ax.set_ylabel('Bearing')

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
ax.scatter(tenCO['SCK1_CO'],tenCO['speed(m/s)'])
ax.set_xlabel('CO')
ax.set_ylabel('Speed')

# %%
np.corrcoef(tenCO['SCK1_CO'],tenCO['SCK1_TC'])
# Out:
# array([[ 1.        , -0.21024827],
#        [-0.21024827,  1.        ]])

# %%
import scipy.stats

# %%
scipy.stats.pearsonr(tenCO['SCK1_CO'],tenCO['SCK1_TC'])
# Out:
# (-0.21024827245053157, 1.6315005030743102e-14)

# %%
np.corrcoef(tenCO['SCK1_CO'],tenCO['SCK1_TC'],tenCO['FS_TF'])
# Out:
# array([[ 1.        , -0.21024827],
#        [-0.21024827,  1.        ]])

# %%
# for column in tenCO:
#     print(tenCO[column])

# %%
df = pd.read_csv('CO_ten_SCK1.csv')

# %%
df.columns[7:-4]
# Out:
# Index([u'bearing(deg)', u'speed(m/s)', u'distance(m)', u'SCK1_CO', u'SCK1_NO2', u'SCK1_TC', u'SCK1_RH', u'SCK1_LX', u'SCK1_DB', u'FS_TF', u'FS_RH', u'FS_WS', u'FS_WD', u'FS_UP', u'FS_DN', u'V_r'], dtype='object')

# %%
df[df.columns[7:-4]].apply(lambda x: x.corr(df['SCK1_CO']))
# Out:
# bearing(deg)    0.080990
# speed(m/s)     -0.050289
# distance(m)    -0.164612
# SCK1_CO         1.000000
# SCK1_NO2        0.023675
# SCK1_TC        -0.210248
# SCK1_RH         0.366656
# SCK1_LX         0.268370
# SCK1_DB         0.139002
# FS_TF          -0.130925
# FS_RH           0.363133
# FS_WS          -0.052929
# FS_WD          -0.268256
# FS_UP          -0.065166
# FS_DN          -0.096387
# V_r            -0.044904
# dtype: float64
