# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from datetime import datetime as dt
import datetime
import csv
import math
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
from coordinateSystems import GeographicSystem
from coordinateSystems import TangentPlaneCartesianSystem

# %%
SCK3_ALL_cases = pd.read_csv('ALL_SCK3_cases.csv')
SCK3_ALL_nocases = pd.read_csv('ALL_SCK3_nocases.csv')
SCK3_ten_cases = pd.read_csv('ten_SCK3_cases.csv')
SCK3_ten_nocases = pd.read_csv('ten_SCK3_nocases.csv')

# %%
def calcs(data):
    print 'mean:',np.mean(data)
    print 'stdev:',np.std(data)

# %%
calcs(SCK3_ALL_cases['SCK3_CO'])
# Out:
# mean: 254.575863722
# stdev: 75.6770502613

# %%
calcs(SCK3_ALL_nocases['SCK3_CO'])
# Out:
# mean: 422.883238343
# stdev: 82.2902653513

# %%
calcs(SCK3_ten_cases['SCK3_CO'])
# Out:
# mean: 214.066912632
# stdev: 89.2689869328

# %%
calcs(SCK3_ten_nocases['SCK3_CO'])
# Out:
# mean: 341.917087824
# stdev: 49.8443060937

# %%
fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(12,1,(1,8))
ax.set_xlim(-990,1390)
ax.set_ylim(-800,1000)
ax.scatter(0,0,c='black',s=100,linewidths=2,marker='x') # point of fixed site
ax.scatter(SCK3_ten_cases['X(m)'],SCK3_ten_cases['Y(m)'],s=2,c='r',linewidth=0)

ax.set_title('SCK2 Carbon Monoxide (K$\Omega$)',fontsize=16)
ax.set_xlabel('East-West (meters)',fontsize=16)
ax.set_ylabel('North-South (meters)',fontsize=16)
majorLocator = MultipleLocator(200)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(100)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
ax.tick_params(labelsize=14)
ax.yaxis.set_major_locator(majorLocator)
ax.yaxis.set_major_formatter(majorFormatter)
ax.yaxis.set_minor_locator(minorLocator)
ax.grid()
#plt.savefig('ALL_CO_ten_SCK2', format='png', dpi=300)

# %%
fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(12,1,(1,8))
ax.set_xlim(-990,1390)
ax.set_ylim(-800,1000)
ax.scatter(0,0,c='black',s=100,linewidths=2,marker='x') # point of fixed site
ax.scatter(SCK3_ten_nocases['X(m)'],SCK3_ten_nocases['Y(m)'],s=2,c='r',linewidth=0)

ax.set_title('SCK2 Carbon Monoxide (K$\Omega$)',fontsize=16)
ax.set_xlabel('East-West (meters)',fontsize=16)
ax.set_ylabel('North-South (meters)',fontsize=16)
majorLocator = MultipleLocator(200)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(100)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
ax.tick_params(labelsize=14)
ax.yaxis.set_major_locator(majorLocator)
ax.yaxis.set_major_formatter(majorFormatter)
ax.yaxis.set_minor_locator(minorLocator)
ax.grid()
#plt.savefig('ALL_CO_ten_SCK2', format='png', dpi=300)

# %%
fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(12,1,(1,8))
ax.set_xlim(-990,1390)
ax.set_ylim(-800,1000)
ax.scatter(0,0,c='black',s=100,linewidths=2,marker='x') # point of fixed site
ax.scatter(SCK3_ALL_nocases['X(m)'],SCK3_ALL_nocases['Y(m)'],s=2,c='r',linewidth=0)

ax.set_title('SCK2 Carbon Monoxide (K$\Omega$)',fontsize=16)
ax.set_xlabel('East-West (meters)',fontsize=16)
ax.set_ylabel('North-South (meters)',fontsize=16)
majorLocator = MultipleLocator(200)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(100)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
ax.tick_params(labelsize=14)
ax.yaxis.set_major_locator(majorLocator)
ax.yaxis.set_major_formatter(majorFormatter)
ax.yaxis.set_minor_locator(minorLocator)
ax.grid()
#plt.savefig('ALL_CO_ten_SCK2', format='png', dpi=300)

# %%
SCK3_NO2_ALL_cases = pd.read_csv('ALL_NO2_SCK3_cases.csv')
SCK3_NO2_ALL_nocases = pd.read_csv('ALL_NO2_SCK3_nocases.csv')
SCK3_NO2_ten_cases = pd.read_csv('ten_NO2_SCK3_cases.csv')
SCK3_NO2_ten_nocases = pd.read_csv('ten_NO2_SCK3_nocases.csv')

# %%
calcs(SCK3_NO2_ALL_cases['SCK3_NO2'])
# Out:
# mean: 25.1048772394
# stdev: 12.1640536951

# %%
calcs(SCK3_NO2_ALL_nocases['SCK3_NO2'])
# Out:
# mean: 45.1316613945
# stdev: 20.3489524012

# %%
calcs(SCK3_NO2_ten_cases['SCK3_NO2'])
# Out:
# mean: 27.3499020333
# stdev: 13.528043103

# %%
calcs(SCK3_NO2_ten_nocases['SCK3_NO2'])
# Out:
# mean: 62.2451501527
# stdev: 31.0280059746

# %%
fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(12,1,(1,8))
ax.set_xlim(-990,1390)
ax.set_ylim(-800,1000)
ax.scatter(0,0,c='black',s=100,linewidths=2,marker='x') # point of fixed site
ax.scatter(SCK3_NO2_ten_cases['X(m)'],SCK3_NO2_ten_cases['Y(m)'],s=2,c='blue',linewidth=0)

ax.set_title('SCK2 Nitrogen Dioxide (K$\Omega$)',fontsize=16)
ax.set_xlabel('East-West (meters)',fontsize=16)
ax.set_ylabel('North-South (meters)',fontsize=16)
majorLocator = MultipleLocator(200)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(100)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
ax.tick_params(labelsize=14)
ax.yaxis.set_major_locator(majorLocator)
ax.yaxis.set_major_formatter(majorFormatter)
ax.yaxis.set_minor_locator(minorLocator)
ax.grid()
#plt.savefig('ALL_NO2_ten_SCK2', format='png', dpi=300)

# %%
fig = plt.figure(figsize=(10,12))
ax = fig.add_subplot(12,1,(1,8))
ax.set_xlim(-990,1390)
ax.set_ylim(-800,1000)
ax.scatter(0,0,c='black',s=100,linewidths=2,marker='x') # point of fixed site
ax.scatter(SCK3_NO2_ten_nocases['X(m)'],SCK3_NO2_ten_nocases['Y(m)'],s=2,c='blue',linewidth=0)

ax.set_title('SCK2 Nitrogen Dioxide (K$\Omega$)',fontsize=16)
ax.set_xlabel('East-West (meters)',fontsize=16)
ax.set_ylabel('North-South (meters)',fontsize=16)
majorLocator = MultipleLocator(200)
majorFormatter = FormatStrFormatter('%d')
minorLocator = MultipleLocator(100)
ax.xaxis.set_major_locator(majorLocator)
ax.xaxis.set_major_formatter(majorFormatter)
ax.xaxis.set_minor_locator(minorLocator)
ax.tick_params(labelsize=14)
ax.yaxis.set_major_locator(majorLocator)
ax.yaxis.set_major_formatter(majorFormatter)
ax.yaxis.set_minor_locator(minorLocator)
ax.grid()
#plt.savefig('ALL_NO2_ten_SCK2', format='png', dpi=300)
